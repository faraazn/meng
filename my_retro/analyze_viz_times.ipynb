# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
vt = []
with open("viz_times.txt", "r") as f:
    for line in f:
        vt.append(float(line.strip()))
vt = np.array(vt)
print(vt[:10])
print(vt.shape)
# Out:
# [0.09622884 0.00267911 0.00524998 0.00174809 0.01464605 0.00158215
#  0.00136924 0.00137496 0.00135779 0.00156808]
# (999,)

# %%
plt.plot(vt)

# %%
plt.plot(vt[:50])

# %%
plt.plot(vt[-100:])
